# %% [markdown]
# # Week-10 chi-square-test
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="chi-square-test")
# Out:
# [jovian] Updating notebook "yash-kavaiya/chi-square-test" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/yash-kavaiya/chi-square-test
# 'https://jovian.ai/yash-kavaiya/chi-square-test'

# %%
import pandas as pd
import numpy as np
from scipy import stats
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 7.2 MB/s eta 0:00:01
# ...

# %%
stats.chi2.ppf(0.99,6)
# Out:
# 16.811893829770927

# %%
url = 'https://github.com/Yash-Kavaiya/data-analytics-with-python-nptel/blob/main/week-10/acad.xlsx?raw=true'

# %%
from urllib.request import urlretrieve
urlretrieve(url, 'acad.xlsx')
# Out:
# ('acad.xlsx', <http.client.HTTPMessage at 0x7f666d0f72e0>)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
acad=pd.read_excel("acad.xlsx")
acad
# Out:
#     Rsp No  aa  pe  sm  ae  r  g  c
# 0        1  99  19   1   2  0  0  1
# 1        2  46  12   0   0  0  0  0
# 2        3  57  15   1   1  0  0  0
# 3        4  94  18   2   2  1  1  1
# 4        5  82  13   2   1  1  1  1
# 5        6  59  12   0   0  2  0  0
# 6        7  61  12   1   2  0  0  0
# 7        8  29   9   0   0  1  1  0
# 8        9  36  13   1   1  0  0  0
# 9       10  91  16   2   2  1  1  0
# 10      11  55  10   0   0  1  0  0
# 11      12  58  11   0   1  0  0  0
# 12      13  67  14   1   1  0  1  1
# 13      14  77  14   1   2  2  1  0
# 14      15  71  12   0   0  2  1  0
# 15      16  83  16   2   2  1  0  1
# 16      17  96  15   2   2  2  0  1
# 17      18  87  12   1   1  0  0  1
# 18      19  62  11   0   0  0  0  0
# 19      20  52   9   0   1  2  1  0
# 20      21  46  10   1   0  0  1  0
# 21      22  91  20   2   2  1  0  0
# 22      23  85  12   2   1  1  1  1
# 23      24  48  11   1   1  2  0  0
# 24      25  81  17   1   1  1  1  1
# ...

# %%
obs=pd.pivot_table(acad[['g','sm']], index='g',columns='sm',aggfunc=len)
obs
# Out:
# sm   0   1  2
# g
# 0   10  13  6
# 1    4   9  8

# %%
from scipy.stats import chi2_contingency
chi2,p,dof,tbl=chi2_contingency(obs)

# %%
chi2
# Out:
# 2.3649585225939904

# %%
p
# Out:
# 0.3065178579178871

# %%
dof
# Out:
# 2

# %%
tbl
# Out:
# array([[ 8.12, 12.76,  8.12],
#        [ 5.88,  9.24,  5.88]])
